# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
FEG2012=pd.read_excel('data/2012FEGuide.xlsx')
FEG2012.columns = FEG2012.columns.str.replace(' ', '')
FEG2012.columns = FEG2012.columns.str.replace('?', '')
FEG2012.columns = FEG2012.columns.str.replace('#', 'num')
FEG2012.columns = FEG2012.columns.str.replace('%', 'percen')

# %%
#for x in FEG2012.columns:
#    print(f'{x}')

# %%
fecon=pd.DataFrame()

# %%
fecon=FEG2012[['MfrName','Carline','ModelYr','CityFE(Guide)-ConventionalFuel',\
'HwyFE(Guide)-ConventionalFuel','CombFE(Guide)-ConventionalFuel',\
'Guzzler','AnnualFuel1Cost-ConventionalFuel']]

# %%
print(fecon['MfrName'].unique())
print(len(fecon['MfrName'].unique()))
# Out:
# ['aston martin' 'Audi' 'Bentley' 'BMW' 'Bugatti' 'General Motors'
#  'Ferrari' 'Honda' 'Lamborghini' 'Toyota' 'MAZDA' 'McLaren Automotive '
#  'Mercedes-Benz' 'Nissan' 'Porsche' 'Chrysler Group LLC' 'Jaguar Cars'
#  'Lotus' 'Mitsubishi Motors NA' 'Ford Motor Company' 'Hyundai' 'Maserati'
#  'Roush' 'Volkswagen' 'Volvo' 'Kia' 'Mitsubishi Motors Co' 'Rolls-Royce'
#  'Saab Cars North America' 'Subaru' 'Suzuki' 'VPG' 'Land Rover']
# 33

# %%
#fecon['MakeModel']=fecon.apply(lambda row: row.MfrName+row.Carline, axis=1)
#df.apply(lambda row: row.a + row.b, axis=1)
fn = lambda row: row.MfrName +' '+ row.Carline # define a function for the new column
col = fecon.apply(fn, axis=1) # get column data with an index
fecon = fecon.assign(MakeModel=col.values) # assign values to column 'c'
fecon.sort_values(by=['MakeModel'])
# Out:
#           MfrName           Carline  ModelYr  CityFE(Guide)-ConventionalFuel  \
# 639          Audi                A3     2012                              21
# 638          Audi                A3     2012                              22
# 641          Audi        A3 QUATTRO     2012                              21
# 257          Audi                A4     2012                              22
# 642          Audi  A4 AVANT QUATTRO     2012                              21
# ..            ...               ...      ...                             ...
# 2    aston martin        V8 Vantage     2012                              14
# 3    aston martin        V8 Vantage     2012                              13
# 1    aston martin        V8 Vantage     2012                              14
# 4    aston martin      V8 Vantage S     2012                              14
# 84   aston martin            Virage     2012                              13
#
#      HwyFE(Guide)-ConventionalFuel  CombFE(Guide)-ConventionalFuel Guzzler  \
# 639                             30                              24     NaN
# 638                             28                              24     NaN
# 641                             28                              24     NaN
# 257                             30                              25     NaN
# 642                             29                              24     NaN
# ..                             ...                             ...     ...
# 2                               21                              16       G
# 3                               19                              15       G
# 1                               20                              16       G
# 4                               21                              16       G
# 84                              18                              15       G
#
#      AnnualFuel1Cost-ConventionalFuel                  MakeModel
# 639                              2002                    Audi A3
# 638                              2002                    Audi A3
# 641                              2002            Audi A3 QUATTRO
# 257                              1920                    Audi A4
# 642                              2002      Audi A4 AVANT QUATTRO
# ..                                ...                        ...
# 2                                3563    aston martin V8 Vantage
# 3                                3800    aston martin V8 Vantage
# 1                                3563    aston martin V8 Vantage
# 4                                3563  aston martin V8 Vantage S
# 84                               3800        aston martin Virage
#
# [1142 rows x 9 columns]

# %%
plt.subplots(figsize=(16,200))
plt.barh(fecon.MakeModel, fecon['CombFE(Guide)-ConventionalFuel'])
plt.margins(.001)
plt.tight_layout()
plt.show()

# %%
fecon
# Out:
#            MfrName       Carline  ModelYr  CityFE(Guide)-ConventionalFuel  \
# 0     aston martin   V12 Vantage     2012                              11
# 1     aston martin    V8 Vantage     2012                              14
# 2     aston martin    V8 Vantage     2012                              14
# 3     aston martin    V8 Vantage     2012                              13
# 4     aston martin  V8 Vantage S     2012                              14
# ...            ...           ...      ...                             ...
# 1137         Volvo      XC60 AWD     2012                              18
# 1138         Volvo      XC70 AWD     2012                              17
# 1139         Volvo      XC70 AWD     2012                              18
# 1140         Volvo      XC90 AWD     2012                              16
# 1141    Volkswagen        Passat     2012                              30
#
#       HwyFE(Guide)-ConventionalFuel  CombFE(Guide)-ConventionalFuel Guzzler  \
# 0                                17                              13       G
# 1                                20                              16       G
# 2                                21                              16       G
# 3                                19                              15       G
# 4                                21                              16       G
# ...                             ...                             ...     ...
# 1137                             24                              20     NaN
# 1138                             23                              20     NaN
# 1139                             24                              20     NaN
# 1140                             23                              18     NaN
# 1141                             40                              34     NaN
#
#       AnnualFuel1Cost-ConventionalFuel                 MakeModel
# 0                                 4385   aston martinV12 Vantage
# 1                                 3563    aston martinV8 Vantage
# 2                                 3563    aston martinV8 Vantage
# 3                                 3800    aston martinV8 Vantage
# 4                                 3563  aston martinV8 Vantage S
# ...                                ...                       ...
# 1137                              2775             VolvoXC60 AWD
# 1138                              2775             VolvoXC70 AWD
# 1139                              2775             VolvoXC70 AWD
# 1140                              3086             VolvoXC90 AWD
# 1141                              1742          VolkswagenPassat
#
# [1142 rows x 9 columns]

# %% [markdown]
# # Way Ahead.
# ## Export fecon. Use it and the violations data to start getting actual plots.
# ### still need to try to find frequency analysis of cars on the road

# %%
fecon.to_csv('data/fecon.csv', index = False)

# %% [markdown]
# fecon is a csv file in the data folder with 1142 rows and 9 columns with information on the fuel efficency of 33 vehicle manufacturers
