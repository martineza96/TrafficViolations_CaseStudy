# %%
import numpy as np
import pandas as pd
import matplotlib as mlt
import matplotlib.pyplot as plt
import scipy.stats as stats
from sklearn.linear_model import LinearRegression

# %%
FREQUENCY=pd.read_csv('data/FREQUENCY.csv')

# %%
frequency=pd.read_csv('data/Model Popularity.csv')

# %%
FREQUENCY
# Out:
#                         Model  Count      FuelEcon  City  Hwy  Combo
# 0                EXPLORER FWD  11311  [20, 28, 23]    20   28     23
# 1             F150 PICKUP 2WD   9253  [16, 22, 18]    16   22     18
# 2                   FOCUS FWD   7633  [28, 38, 31]    28   38     31
# 3                     MUSTANG   7427  [19, 31, 23]    19   31     23
# 4                  ESCAPE FWD   5721  [21, 28, 23]    21   28     23
# 5                  FUSION AWD   4809  [17, 25, 19]    17   25     19
# 6          EXPEDITION 2WD FFV   4356  [14, 20, 16]    14   20     16
# 7                  TAURUS AWD   4115  [17, 26, 20]    17   26     20
# 8                E150 VAN FFV   4115  [13, 17, 15]    13   17     15
# 9                E250 VAN FFV   2307  [13, 17, 15]    13   17     15
# 10                   E350 VAN   1718  [10, 14, 12]    10   14     12
# 11                   EDGE FWD   1313  [21, 30, 24]    21   30     24
# 12        F150 PICKUP 2WD FFV   1050  [17, 23, 19]    17   23     19
# 13        Transit Connect Van    918  [21, 27, 23]    21   27     23
# 14                 Fiesta FWD    809  [29, 39, 33]    29   39     33
# 15                   FLEX FWD    309  [17, 24, 19]    17   24     19
# 16              Focus FWD FFV    288  [28, 38, 31]    28   38     31
# 17               E350 VAN FFV    174  [12, 16, 13]    12   16     13
# 18             FUSION AWD FFV    169  [18, 26, 20]    18   26     20
# 19  TRANSIT CONNECT WAGON FWD    158  [22, 27, 24]    22   27     24
# 20          ESCAPE HYBRID FWD    124  [34, 31, 32]    34   31     32
# 21          Focus SFE FWD FFV    123  [28, 40, 33]    28   40     33
# 22     F150 Raptor Pickup 4WD     62  [11, 16, 13]    11   16     13
# 23             ESCAPE FWD FFV     58  [19, 25, 21]    19   25     21
# 24          FUSION HYBRID FWD     55  [41, 36, 39]    41   36     39
# 25             Fiesta SFE FWD     22  [29, 40, 33]    29   40     33
# 26        MUSTANG CONVERTIBLE     15  [19, 30, 23]    19   30     23
# 27             E150 WAGON FFV     15  [13, 16, 14]    13   16     14
# 28                    MKZ AWD     15  [17, 25, 19]    17   25     19
# 29             MKZ HYBRID FWD     13  [41, 36, 39]    41   36     39
# 30            F150 PICKUP 4WD      6  [15, 21, 17]    15   21     17
# 31               EXPLORER AWD      6  [17, 23, 19]    17   23     19
# 32                 E350 WAGON      4  [10, 13, 11]    10   13     11
# 33                    MKZ FWD      3  [18, 27, 21]    18   27     21
# 34               FUSION S FWD      2  [22, 32, 25]    22   32     25
# 35         EXPEDITION 4WD FFV      1  [13, 18, 15]    13   18     15

# %%
plt.scatter(FREQUENCY.Combo,FREQUENCY.Count,label='Combined')
plt.scatter(FREQUENCY.Hwy,FREQUENCY.Count,label='Hwy', color='green')
plt.scatter(FREQUENCY.City,FREQUENCY.Count,label='City', color='red')
plt.legend()
plt.show()

# %%
corr=FREQUENCY.corr()['City']['Count']

res=corr*(34/(1-(corr)**2))**.5
res
# Out:
# -0.5906202354189433

# %%
stats.t(df=34).cdf(res)*2
# Out:
# 0.5586807335613755

# %%
tdistro=stats.t(df=34).pdf(np.linspace(-3,3,200))
plt.plot(np.linspace(-3,3,200),tdistro)
plt.show()

# %% [markdown]
# count/sales= countper sale
#
# vio per vic sold vs combined fuel econ
#
# population is traffic ticket violtions
#
# of the traffic violations as fuel conusmption increases ?????
#
#
# normalized for puchase rate there is a a _______ corolation betweent fuel econmy and violation frequency
#
# corolation hypothesis test. tell me that if my r value is less than
#
# maryland is represntiive
#
# find area to the left of this on bell curve and right of +.59
# comes out of a t distribuion with 34 deg of freedom
#
# if that summed area is less than .05 there is evidence to reject the null hypo.
#
# null hypo is that there is a zero corolation
#
# since .55 is more than .05 we do not have enough evidence to reject the null hypo

# %%
FREQUENCY['Sales']=pd.Series([171325,605819,95144,61495,203574,119355,40512,21718,18047,10119,7535,98938,68746,1064639,35551,16158,3590,763,4194,23218,4412,1533,4059,2063,1365,967,124,66,7220,6257,393,91,18,1444,50,9])

# %%
fn = lambda row: row['Count']/row['Sales']
col = FREQUENCY.apply(fn, axis=1) # get column data with an index
FREQUENCY = FREQUENCY.assign(Normed=col.values) # assign values to column 'c'

# %%
FREQUENCY
# Out:
#                         Model  Count      FuelEcon  City  Hwy  Combo    Sales  \
# 0                EXPLORER FWD  11311  [20, 28, 23]    20   28     23   171325
# 1             F150 PICKUP 2WD   9253  [16, 22, 18]    16   22     18   605819
# 2                   FOCUS FWD   7633  [28, 38, 31]    28   38     31    95144
# 3                     MUSTANG   7427  [19, 31, 23]    19   31     23    61495
# 4                  ESCAPE FWD   5721  [21, 28, 23]    21   28     23   203574
# 5                  FUSION AWD   4809  [17, 25, 19]    17   25     19   119355
# 6          EXPEDITION 2WD FFV   4356  [14, 20, 16]    14   20     16    40512
# 7                  TAURUS AWD   4115  [17, 26, 20]    17   26     20    21718
# 8                E150 VAN FFV   4115  [13, 17, 15]    13   17     15    18047
# 9                E250 VAN FFV   2307  [13, 17, 15]    13   17     15    10119
# 10                   E350 VAN   1718  [10, 14, 12]    10   14     12     7535
# 11                   EDGE FWD   1313  [21, 30, 24]    21   30     24    98938
# 12        F150 PICKUP 2WD FFV   1050  [17, 23, 19]    17   23     19    68746
# 13        Transit Connect Van    918  [21, 27, 23]    21   27     23  1064639
# 14                 Fiesta FWD    809  [29, 39, 33]    29   39     33    35551
# 15                   FLEX FWD    309  [17, 24, 19]    17   24     19    16158
# 16              Focus FWD FFV    288  [28, 38, 31]    28   38     31     3590
# 17               E350 VAN FFV    174  [12, 16, 13]    12   16     13      763
# 18             FUSION AWD FFV    169  [18, 26, 20]    18   26     20     4194
# 19  TRANSIT CONNECT WAGON FWD    158  [22, 27, 24]    22   27     24    23218
# 20          ESCAPE HYBRID FWD    124  [34, 31, 32]    34   31     32     4412
# 21          Focus SFE FWD FFV    123  [28, 40, 33]    28   40     33     1533
# 22     F150 Raptor Pickup 4WD     62  [11, 16, 13]    11   16     13     4059
# 23             ESCAPE FWD FFV     58  [19, 25, 21]    19   25     21     2063
# 24          FUSION HYBRID FWD     55  [41, 36, 39]    41   36     39     1365
# 25             Fiesta SFE FWD     22  [29, 40, 33]    29   40     33      967
# 26        MUSTANG CONVERTIBLE     15  [19, 30, 23]    19   30     23      124
# 27             E150 WAGON FFV     15  [13, 16, 14]    13   16     14       66
# 28                    MKZ AWD     15  [17, 25, 19]    17   25     19     7220
# 29             MKZ HYBRID FWD     13  [41, 36, 39]    41   36     39     6257
# 30            F150 PICKUP 4WD      6  [15, 21, 17]    15   21     17      393
# 31               EXPLORER AWD      6  [17, 23, 19]    17   23     19       91
# 32                 E350 WAGON      4  [10, 13, 11]    10   13     11       18
# 33                    MKZ FWD      3  [18, 27, 21]    18   27     21     1444
# 34               FUSION S FWD      2  [22, 32, 25]    22   32     25       50
# 35         EXPEDITION 4WD FFV      1  [13, 18, 15]    13   18     15        9
#
#       Normed
# 0   0.066021
# 1   0.015274
# 2   0.080226
# 3   0.120774
# 4   0.028103
# 5   0.040292
# 6   0.107524
# 7   0.189474
# 8   0.228016
# 9   0.227987
# 10  0.228003
# 11  0.013271
# 12  0.015274
# 13  0.000862
# 14  0.022756
# 15  0.019124
# 16  0.080223
# 17  0.228047
# 18  0.040296
# 19  0.006805
# 20  0.028105
# 21  0.080235
# 22  0.015275
# 23  0.028114
# 24  0.040293
# 25  0.022751
# 26  0.120968
# 27  0.227273
# 28  0.002078
# 29  0.002078
# 30  0.015267
# 31  0.065934
# 32  0.222222
# 33  0.002078
# 34  0.040000
# 35  0.111111

# %%
plt.subplots()
plt.scatter(FREQUENCY.Combo,FREQUENCY.Normed,label='Combined')
plt.show()

# %%
X = FREQUENCY.Combo.values.reshape(-1, 1)  # values converts it into a numpy array
Y = FREQUENCY.Normed.values.reshape(-1, 1)  # -1 means that calculate the dimension of rows, but have 1 column
linear_regressor = LinearRegression()  # create object for the class
linear_regressor.fit(X, Y)  # perform linear regression
Y_pred = linear_regressor.predict(X)  # make predictions

# %%
plt.scatter(X, Y)
plt.plot(X, Y_pred, color='red')
plt.show()

# %%
corr=FREQUENCY.corr()['Combo']['Normed']

res=corr*(34/(1-(corr)**2))**.5
res
# Out:
# -3.320913929629245

# %%
stats.t(df=34).cdf(res)*2
# Out:
# 0.0021514314259223964

# %%
plt.subplots()
plt.scatter(FREQUENCY.Hwy,FREQUENCY.Normed,label='Hwy', color='green')
plt.show()

# %%
X = FREQUENCY.Hwy.values.reshape(-1, 1)  # values converts it into a numpy array
Y = FREQUENCY.Normed.values.reshape(-1, 1)  # -1 means that calculate the dimension of rows, but have 1 column
linear_regressor = LinearRegression()  # create object for the class
linear_regressor.fit(X, Y)  # perform linear regression
Y_pred = linear_regressor.predict(X)  # make predictions

plt.scatter(X, Y, color='green')
plt.plot(X, Y_pred, color='red')
plt.show()

# %%
corr=FREQUENCY.corr()['Hwy']['Normed']

res=corr*(34/(1-(corr)**2))**.5
res
# Out:
# -3.577715325382763

# %%
stats.t(df=34).cdf(res)*2
# Out:
# 0.001065879042448288

# %%
plt.subplots()
plt.scatter(FREQUENCY.City,FREQUENCY.Normed,label='City', color='red')
plt.show()

# %%
X = FREQUENCY.City.values.reshape(-1, 1)  # values converts it into a numpy array
Y = FREQUENCY.Normed.values.reshape(-1, 1)  # -1 means that calculate the dimension of rows, but have 1 column
linear_regressor = LinearRegression()  # create object for the class
linear_regressor.fit(X, Y)  # perform linear regression
Y_pred = linear_regressor.predict(X)  # make predictions

plt.scatter(X, Y, color='red')
plt.plot(X, Y_pred, color='red')
plt.show()

# %%
corr=FREQUENCY.corr()['City']['Normed']

res=corr*(34/(1-(corr)**2))**.5
res
# Out:
# -3.176949591222216

# %%
stats.t(df=34).cdf(res)*2
# Out:
# 0.00316157795830453
